# %% [markdown]
# <a href="https://colab.research.google.com/github/sushil4625/StockMarketAnalysis/blob/main/eda_stock_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setting path and data frame formation
df=pd.read_csv("/content/dataaftercleaning (1).csv")
df.head(3)
# Out:
#    Unnamed: 0      Sector         Company            BSE        Date    Open  \
# 0           0  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-02  1595.0
# 1           1  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-03  1478.0
# 2           2  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-04  1496.0
#
#           High          Low        Close    Adj Close    Volume  Low_52  \
# 0  1603.949951  1441.150024  1475.000000  1097.873779  285450.0  1793.1
# 1  1505.000000  1451.099976  1496.699951  1114.025757  264423.0  1793.1
# 2  1505.000000  1416.000000  1426.300049  1061.625366  179477.0  1793.1
#
#    High_52   PE_Ratio  Total_Revenue  Gross_Profit    Market_Cap  \
# 0   4361.2  23.431198   1.174240e+11  8.310660e+10  1.174240e+11
# 1   4361.2  23.431198   1.174240e+11  8.310660e+10  1.174240e+11
# 2   4361.2  23.431198   1.174240e+11  8.310660e+10  1.174240e+11
#
#     Net_Company   PE_ratio
# 0  5.881630e+10  23.431198
# 1  5.881630e+10  23.431198
# ...

# %%
df1=df.drop(["Unnamed: 0"],axis=1)
df1.head(3)
# Out:
#        Sector         Company            BSE        Date    Open         High  \
# 0  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-02  1595.0  1603.949951
# 1  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-03  1478.0  1505.000000
# 2  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO  2012-01-04  1496.0  1505.000000
#
#            Low        Close    Adj Close    Volume  Low_52  High_52  \
# 0  1441.150024  1475.000000  1097.873779  285450.0  1793.1   4361.2
# 1  1451.099976  1496.699951  1114.025757  264423.0  1793.1   4361.2
# 2  1416.000000  1426.300049  1061.625366  179477.0  1793.1   4361.2
#
#     PE_Ratio  Total_Revenue  Gross_Profit    Market_Cap   Net_Company  \
# 0  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
# 1  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
# 2  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
#
#     PE_ratio
# 0  23.431198
# 1  23.431198
# 2  23.431198

# %%
df1.tail(3)
# Out:
#                         Sector                Company           BSE  \
# 79978  Pharmaceuticals & Drugs  NATURAL CAPSULES LTD   NATCAPSUQ.BO
# 79979  Pharmaceuticals & Drugs  NATURAL CAPSULES LTD   NATCAPSUQ.BO
# 79980  Pharmaceuticals & Drugs  NATURAL CAPSULES LTD   NATCAPSUQ.BO
#
#              Date        Open        High    Low       Close   Adj Close  \
# 79978  2023-03-02  404.000000  414.000000  397.0  405.700012  405.700012
# 79979  2023-03-03  400.000000  411.899994  397.0  398.750000  398.750000
# 79980  2023-03-06  404.899994  411.000000  400.0  404.600006  404.600006
#
#         Volume  Low_52  High_52  PE_Ratio  Total_Revenue  Gross_Profit  \
# 79978   7911.0   32.65    411.0  84.71524   1.762950e+09   965328000.0
# 79979  18686.0   32.65    411.0  84.71524   1.762950e+09   965328000.0
# 79980   6126.0   32.65    411.0  84.71524   1.762950e+09   965328000.0
#
#          Market_Cap  Net_Company  PE_ratio
# 79978  1.174240e+11  209039000.0  84.71524
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79981 entries, 0 to 79980
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector         79981 non-null  object
#  1   Company        79981 non-null  object
#  2   BSE            79981 non-null  object
#  3   Date           79981 non-null  object
#  4   Open           79981 non-null  float64
#  5   High           79981 non-null  float64
#  6   Low            79981 non-null  float64
#  7   Close          79981 non-null  float64
#  8   Adj Close      79981 non-null  float64
#  9   Volume         79981 non-null  float64
#  10  Low_52         79981 non-null  float64
#  11  High_52        79981 non-null  float64
#  12  PE_Ratio       79981 non-null  float64
#  13  Total_Revenue  79981 non-null  float64
#  14  Gross_Profit   79981 non-null  float64
#  15  Market_Cap     79981 non-null  float64
#  16  Net_Company    79981 non-null  float64
# ...

# %%
df1["Date"]=pd.to_datetime(df1["Date"])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79981 entries, 0 to 79980
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector         79981 non-null  object
#  1   Company        79981 non-null  object
#  2   BSE            79981 non-null  object
#  3   Date           79981 non-null  datetime64[ns]
#  4   Open           79981 non-null  float64
#  5   High           79981 non-null  float64
#  6   Low            79981 non-null  float64
#  7   Close          79981 non-null  float64
#  8   Adj Close      79981 non-null  float64
#  9   Volume         79981 non-null  float64
#  10  Low_52         79981 non-null  float64
#  11  High_52        79981 non-null  float64
#  12  PE_Ratio       79981 non-null  float64
#  13  Total_Revenue  79981 non-null  float64
#  14  Gross_Profit   79981 non-null  float64
#  15  Market_Cap     79981 non-null  float64
#  16  Net_Company    79981 non-null  float64
# ...

# %%
df1["year"]=df1["Date"].dt.year

df1.head(3)
# Out:
#        Sector         Company            BSE       Date    Open         High  \
# 0  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO 2012-01-02  1595.0  1603.949951
# 1  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO 2012-01-03  1478.0  1505.000000
# 2  Automobile  BAJAJ AUTO LTD  BAJAJ-AUTO.BO 2012-01-04  1496.0  1505.000000
#
#            Low        Close    Adj Close    Volume  Low_52  High_52  \
# 0  1441.150024  1475.000000  1097.873779  285450.0  1793.1   4361.2
# 1  1451.099976  1496.699951  1114.025757  264423.0  1793.1   4361.2
# 2  1416.000000  1426.300049  1061.625366  179477.0  1793.1   4361.2
#
#     PE_Ratio  Total_Revenue  Gross_Profit    Market_Cap   Net_Company  \
# 0  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
# 1  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
# 2  23.431198   1.174240e+11  8.310660e+10  1.174240e+11  5.881630e+10
#
#     PE_ratio  year
# 0  23.431198  2012
# 1  23.431198  2012
# 2  23.431198  2012

# %%
df1.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  79981.000000  79981.000000  79981.000000  79981.000000  79981.000000
# mean     952.306015    964.159292    939.047559    951.004324    886.519872
# std      906.475255    917.072036    894.489596    905.360275    844.650866
# min        1.590000      1.670000      0.005000      1.670000      1.670000
# 25%      284.399994    288.333344    280.299988    284.299988    261.161102
# 50%      596.849976    604.950012    588.000000    595.650024    558.626648
# 75%     1313.099976   1329.000000   1295.250000   1311.474976   1221.394043
# max     2856.149948   2889.999985   2817.675018   2852.237457   2661.743454
#
#               Volume        Low_52       High_52      PE_Ratio  Total_Revenue  \
# count   79981.000000  79981.000000  79981.000000  79981.000000   7.998100e+04
# mean   118930.578800    830.741339   2799.825427    123.643503   8.589999e+10
# ...

# %%
df1.shape
# Out:
# (79981, 19)

# %%
df1.dtypes
# Out:
# Sector                   object
# Company                  object
# BSE                      object
# Date             datetime64[ns]
# Open                    float64
# High                    float64
# Low                     float64
# Close                   float64
# Adj Close               float64
# Volume                  float64
# Low_52                  float64
# High_52                 float64
# PE_Ratio                float64
# Total_Revenue           float64
# Gross_Profit            float64
# Market_Cap              float64
# Net_Company             float64
# PE_ratio                float64
# year                      int64
# dtype: object

# %%
df3=df1.groupby('Sector')

# %%
len(df3)
# Out:
# 4

# %%
df3.first()
# Out:
#                                                  Company            BSE  \
# Sector
# Automobile                                BAJAJ AUTO LTD  BAJAJ-AUTO.BO
# Fast Moving Consumer Goods  GODREJ CONSUMER PRODUCTS LTD    GODREJCP.BO
# IT                            Persistent Systems Limited  PERSISTENT.BO
# Pharmaceuticals & Drugs         Aurobindo Pharma Limited  AUROPHARMA.BO
#
#                                  Date    Open         High          Low  \
# Sector
# Automobile                 2012-01-02  1595.0  1603.949951  1441.150024
# Fast Moving Consumer Goods 2012-01-02   129.0   129.283340   123.666664
# IT                         2012-01-02   165.0   165.500000   160.000000
# Pharmaceuticals & Drugs    2012-01-02    43.0    43.450001    42.525002
#
#                                   Close    Adj Close    Volume   Low_52  \
# Sector
# Automobile                  1475.000000  1097.873779  285450.0  1793.10
# ...

# %%
df3.last()
# Out:
#                                           Company            BSE       Date  \
# Sector
# Automobile                  TVS MOTOR COMPANY LTD    TVSMOTOR.BO 2023-03-06
# Fast Moving Consumer Goods   Asian Paints Limited  ASIANPAINT.BO 2023-03-06
# IT                                 TATA ELXSI LTD   TATAELXSI.BO 2023-03-06
# Pharmaceuticals & Drugs     NATURAL CAPSULES LTD    NATCAPSUQ.BO 2023-03-06
#
#                                    Open         High          Low  \
# Sector
# Automobile                  1069.050049  1102.300049  1069.050049
# Fast Moving Consumer Goods  2835.050049  2883.800049  2817.675018
# IT                          2856.149948  2889.999985  2817.675018
# Pharmaceuticals & Drugs      404.899994   411.000000   400.000000
#
#                                   Close    Adj Close   Volume   Low_52  \
# Sector
# Automobile                  1097.849976  1097.849976  28703.0   240.10
# Fast Moving Consumer Goods  2852.237457  2661.743454  64814.0  1431.85
# ...

# %%
df1.columns
# Out:
# Index(['Sector', 'Company', 'BSE', 'Date', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'Low_52', 'High_52', 'PE_Ratio', 'Total_Revenue',
#        'Gross_Profit', 'Market_Cap', 'Net_Company', 'PE_ratio', 'year'],
#       dtype='object')

# %%
df1.corr()
# Out:
#                    Open      High       Low     Close  Adj Close    Volume  \
# Open           1.000000  0.999916  0.999910  0.999849   0.997883 -0.280833
# High           0.999916  1.000000  0.999880  0.999935   0.998014 -0.279865
# Low            0.999910  0.999880  1.000000  0.999925   0.997899 -0.280992
# Close          0.999849  0.999935  0.999925  1.000000   0.998021 -0.280182
# Adj Close      0.997883  0.998014  0.997899  0.998021   1.000000 -0.284934
# Volume        -0.280833 -0.279865 -0.280992 -0.280182  -0.284934  1.000000
# Low_52         0.754145  0.753938  0.754490  0.754279   0.742375 -0.263639
# High_52        0.603282  0.603436  0.603169  0.603274   0.597123 -0.263331
# PE_Ratio      -0.086097 -0.086167 -0.086016 -0.086036  -0.087666  0.070370
# Total_Revenue  0.223526  0.223320  0.223814  0.223600   0.219604  0.107585
# Gross_Profit   0.166396  0.165965  0.167033  0.166554   0.159305  0.260587
# ...

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df1["Close"])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
sns.pairplot(df1, hue='Sector', height=2)
